# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('patten.jpg')

n = 15
kernel = np.ones((n,n),np.float32)/(n**2)
dst = cv2.filter2D(img,-1,kernel)

plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
np.ones((5,5),np.float32)/25
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]], dtype=float32)

# %%
sum(sum(kernel))
# Out:
# 0.9999998286366463

# %%
n = 11
#kernel = np.ones((n,n),np.float32)/(n**2)
#dst = cv2.filter2D(img,-1,kernel) 이 3줄이 아래 한 줄 한줄과 동일한 값

blur = cv2.blur(img,(5,5))
blur = cv2.GaussianBlur(img,(5,5),0) #GaussianBlur
blur = cv2.medianBlur(img,5) #median
#blur = cv2.bilateralFilter(img, 9, 75, 75)


plt.subplot(221),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(dst),plt.title('blur')
plt.xticks([]), plt.yticks([])
plt.subplot(223),plt.imshow(dst),plt.title('GaussianBlur')
plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(dst),plt.title('median')
plt.xticks([]), plt.yticks([])
plt.show()
